# %%
import PyLog as pl
import PyGol as pygol
from itertools import chain
from texttable import Texttable

# %%
BK_1 = ["starboard(X,Y) :- sector(X,Y,S), >=(S,1), =<(S,15)",
"port(X,Y)      :- sector(X,Y,S), >=(S,17), =<(S,31)",
"forward(X,Y)   :- sector(X,Y,S), >=(S,0), =<(S,7)",
"forward(X,Y)   :- sector(X,Y,S), >=(S,25), =<(S,31)",
"aft(X,Y)       :- sector(X,Y,S), >=(S,9), =<(S,23)", 
"ahead(X,Y) :- sector(X,Y,S), ==(S,0)",
    "bow(X,Y) :- sector(X,Y,S), >=(S,1), =<(S,4)",
    "broad(X,Y) :- sector(X,Y,S), ==(S,4)",
    "forward_beam(X,Y) :- sector(X,Y,S), >=(S,5), =<(S,7)",
    "beam(X,Y) :- sector(X,Y,S), ==(S,8)",
    "aft_beam(X,Y) :- sector(X,Y,S), >=(S,9), =<(S,11)",
    "broad(X,Y) :- sector(X,Y,S), ==(S,12)",
    "quarter(X,Y) :- sector(X,Y,S), >=(S,12), =<(S,15)",
    "astern(X,Y) :- sector(X,Y,S), ==(S,16)",
    "quarter(X,Y) :- sector(X,Y,S), >=(S,17), =<(S,20)",
    "broad(X,Y) :- sector(X,Y,S), ==(S,20)",
    "aft_beam(X,Y) :- sector(X,Y,S), >=(S,21), =<(S,23)",
    "beam(X,Y) :- sector(X,Y,S), ==(S,24)",
    "forward_beam(X,Y) :- sector(X,Y,S), >=(S,25), =<(S,27)",
    "broad(X,Y) :- sector(X,Y,S), ==(S,28)",
    "bow(X,Y) :- sector(X,Y,S), >=(S,28), =<(S,31)",

    "applies(X,Y,rule13_overtaking) :- risk_collision(Y,X), sector(Y,X,S), >=(S,10), =<(S,22)",
    "applies(X,Y,rule14_headon) :- risk_collision(X,Y), sector(X,Y,S1), ==(S1,0), sector(Y,X,S2), ==(S2,0)",
    "applies(X,Y,rule15_crossing) :- risk_collision(X,Y), sector(X,Y,S), >=(S,2), =<(S,9)",
    "applies(X,Y,rule15_crossing) :- risk_collision(X,Y), sector(X,Y,S), >=(S,23), <(S,30)",
    #"applies(X,Y,rule16_giveway) :- applies(X,Y,rule13_overtaking), aft(X,Y)",
    #"applies(X,Y,rule16_giveway) :- applies(X,Y,rule15_crossing), starboard(X,Y)",
    #"applies(X,Y,rule16_giveway) :- applies(X,Y,rule14_crossing)",
    #"applies(X,Y,rule17_standon) :- applies(X,Y,rule13_overtaking), aft(Y,X)",
    #"applies(X,Y,rule17_standon) :- applies(X,Y,rule15_crossing), port(X,Y)",
    "applies(X,Y, rule9_narrow) :- sector(X, Y, S), constraint_narrow(Y)",
    "applies(X,Y, rule18_privilege) :-  sector(X, Y, S), constraint_fishing(X)",
    "applies(X,Y, rule18_privilege) :-  sector(X, Y, S), constraint_draught(X)"
 
]

# %%
scenario = ["sector(a, b, 4)", "risk_collision(a, b)", "constraint_draught(a)",
            "sector(e, f, 2)", "risk_collision(e, f)", "constraint_draught(e)",
            "sector(c, d, 4)", "risk_collision(c, d)",
            ]

pos_example = ["priority(a,b,rule16_giveway,rule17_standon,rule16_standon)",
               "priority(e,f,rule16_giveway,rule17_standon,rule16_standon)" ]

neg_example = ["priority(c,d,rule16_giveway,rule17_standon,rule16_standon)"]

# %%
kb_1 = pl.KnowledgeBase()
kb_1.add_clauses(BK_1)
kb_1.add_clauses(scenario)



P1, N1 = pygol.relevant_literals(file=scenario, constant_set = [],  container = "memory",
                                positive_example=pos_example,
                                negative_example= neg_example, tqdm_disable=True) 

P2 = pl.modify_bcrl(P1, BK_1, [])
N2 = pl.modify_bcrl(N1, BK_1, [])


finak_bk_1 = list(chain.from_iterable(P2.values()))
finak_bk_2 = list(chain.from_iterable(N2.values()))

const = ["rule16_giveway", "rule17_standon","rule16_giveway", "rule15_crossing","rule18_privilege","rule16_standon" ]
constr = [ "sector", "risk_collision", "constraint_draught"]
finak_bk = finak_bk_1+finak_bk_2

P, N = pygol.bottom_clause_generation(file=finak_bk,  
                                       constant_set = const ,  
                                       container = "memory",
                                positive_example=pos_example, 
                                negative_example=neg_example, constrains=constr,tqdm_disable=True)



Train_P = {i:j for i,j in P.items()}
Train_N = {i:j for i,j in N.items()}

model_1 = pygol.pygol_learn(Train_P, Train_N,  constant_set = const,  max_literals=3,  exact_literals=True, 
                    key_size=len(Train_P), min_pos=1, distinct=False, eval_metrics=False, verbose=True)
print("Learned Model: ")
print(model_1.hypothesis)
print(model_1.time_learn)
# Out:
# {'priority(a,b,rule16_giveway,rule17_standon,rule16_standon)': ['sector(a, b, 4)', 'risk_collision(a, b)', 'constraint_draught(a)'], 'priority(e,f,rule16_giveway,rule17_standon,rule16_standon)': ['sector(e, f, 2)', 'risk_collision(e, f)', 'constraint_draught(e)']}
# Positive Example0
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-starboard(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&forward(A,B)
# Positive Example1
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-starboard(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule18_privilege)
# Negative Example0
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&starboard(A,B)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&applies(A,B,rule15_crossing)
# 	 priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&forward(A,B)
# Pruned Positive Hypothesis {'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-starboard(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-forward(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&starboard(A,B)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&applies(A,B,rule15_crossing)&applies(A,B,rule18_privilege)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule15_crossing)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&starboard(A,B)&applies(A,B,rule18_privilege)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&applies(A,B,rule15_crossing)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-broad(A,B)&forward(A,B)&applies(A,B,rule18_privilege)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&starboard(A,B)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule15_crossing)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&forward(A,B)&applies(A,B,rule18_privilege)': [0, 1], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&starboard(A,B)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&applies(A,B,rule15_crossing)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&applies(A,B,rule18_privilege)': [0], 'priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-bow(A,B)&broad(A,B)&forward(A,B)': [0]}
# Learned Model:
# ['priority(A,B,rule16_giveway,rule17_standon,rule16_standon):-starboard(A,B),applies(A,B,rule15_crossing),applies(A,B,rule18_privilege)']
# 0.004712820053100586
